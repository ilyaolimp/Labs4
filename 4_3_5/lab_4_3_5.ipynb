# %% [markdown]
# # Лабораторная работа 4.3.5 — Голография

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Часть А. Голограмма точечного источника

# %% [markdown]
# ## A.I Метод 1 — дифракция Фраунгофера

# %%
data_fraunhofer = pd.DataFrame({
    'L': [],
    'Δx': [],
    'λ': [],
    'D = λ·L/Δx': [],
    'Примечание': []
})

data_fraunhofer

# %% [markdown]
# ## A.I Метод 2 — через линзу

# %%
data_lens_calibration = pd.DataFrame({
    'a, мм': [55],
    'b, мм': [1215],
    'Γ = b/a': [],
    "D'": [],
    'D = D'/Γ': [],
    'Примечание': []
})
F = 43 мм
data_lens_calibration

# %% [markdown]
# ## A.II Радиусы голографических колец

# %%
data_rings = pd.DataFrame({
    'm': [],
    "p'_m (на экране)": [],
    'Γ': [],
    'p_m = p'/Γ': [],
    'p_m^2': [],
    'Комментарий': []
})
a = 43
b = 1010
F = 43 мм
data_rings

# %% [markdown]
# ## A.III Метод по изображениям

# %%
data_images = pd.DataFrame({
    'Положение голограммы': [],
    'Положение экрана': [],
    'Положение O2 (мнимое)': [],
    'Положение O3 (действительное)': [],
    'Примечание': []
})

Мнимое изображение 850 мм и 12 мм

настоящее
75 и 980
data_images

# %% [markdown]
# # Часть Б. Голограмма объёмного предмета

# %% [markdown]
# ## Наблюдение мнимого изображения

# %%
data_virtual = pd.DataFrame({
    'Угол/конфигурация': [],
    'Положение глаза': [],
    'Что видно': [],
    'Глубина/масштаб': [],
    'Комментарий': []
})

data_virtual

# %% [markdown]
# ## Поворот голограммы на 180°

# %%
data_rotation = pd.DataFrame({
    'До поворота': [],
    'После поворота': [],
    'Вывод': []
})
120 мм на фото
расплывается и растет - последний пункт
data_rotation
