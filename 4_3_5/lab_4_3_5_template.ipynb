# %% [markdown]
# # Лабораторная работа 4.3.5 — Голография
# *Шаблон для снятия данных (создан 2026-02-13).*
#
# Этот ноутбук — заготовка: здесь есть таблички для измерений и места для заметок.

# %% [markdown]
# ## Справочные константы
# - Длина волны He–Ne лазера: λ = 632.8 нм
# - Единицы измерения выбрать заранее и придерживаться их во всей работе.
#
# Запиши используемые единицы:
# - Расстояния: …
# - Размеры на экране: …

# %% [markdown]
# # Часть А. Голограмма точечного источника

# %% [markdown]
# ## A.I. Калибровка предметной шкалы
#
# ### Метод 1 — дифракция Фраунгофера
# | № | L | Δx | λ | D = λ·L/Δx | Примечание |
# | --- | --- | --- | --- | --- | --- |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
#
# ### Метод 2 — через линзу
# | № | a | b | Γ=b/a | D' | D=D'/Γ | Примечание |
# | --- | --- | --- | --- | --- | --- | --- |
# |  |  |  |  |  |  |  |
# |  |  |  |  |  |  |  |
# |  |  |  |  |  |  |  |
# |  |  |  |  |  |  |  |
# |  |  |  |  |  |  |  |
# |  |  |  |  |  |  |  |
# |  |  |  |  |  |  |  |
# |  |  |  |  |  |  |  |
#
# ### Итоговое значение D
# | D(метод1) | D(метод2) | Выбранное D | Комментарий |
# | --- | --- | --- | --- |
# |  |  |  |  |
# |  |  |  |  |

# %% [markdown]
# ## A.II. Радиусы голографических колец
# | m | p'_m (на экране) | Γ | p_m=p'/Γ | p_m^2 | Комментарий |
# | --- | --- | --- | --- | --- | --- |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
#
# После заполнения построить график зависимости p_m^2 от m и определить d.

# %% [markdown]
# ## A.III. Метод по изображениям (мнимое/действительное)
# | № | Положение голограммы | Положение экрана | Положение O2 | Положение O3 | Примечание |
# | --- | --- | --- | --- | --- | --- |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |

# %% [markdown]
# # Часть Б. Голограмма объёмного предмета
#
# ## Наблюдение мнимого изображения
# | № | Угол/конфигурация | Положение глаза | Что видно | Глубина | Комментарий |
# | --- | --- | --- | --- | --- | --- |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
# |  |  |  |  |  |  |
#
# ## Поворот голограммы на 180°
# | № | До поворота | После поворота | Вывод |
# | --- | --- | --- | --- |
# |  |  |  |  |
# |  |  |  |  |
# |  |  |  |  |
# |  |  |  |  |
# |  |  |  |  |
# |  |  |  |  |

# %% [markdown]
# # Итоги
# - d (по кольцам): …
# - d (по изображениям): …
# - Расхождение и возможные причины: …
# - Качественные наблюдения: …
